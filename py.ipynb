# %%
def nomeDaFuncao():
    print('Voce invocou a função chamada nomeDaFunção, Parabéns!')
    # x = input('Qual o seu nome?')
    # print(x)
    # print('então,' + x + ', vá se foder e não me invoque novamente!')
    
print('Olá, eu sou um bom software, tenho uma função chamada nomeDaFuncao(), tente usar!')
# Out:
# Olá, eu sou um bom software, tenho uma função chamada nomeDaFuncao(), tente usar!

# %%
# solicite ao usuário para inserir um número inteiro e verifique se ele é par ou ímpar
# Em seguida, imprima na tela uma mensagem informando se o número é par ou ímpar.
n = int(input('Escreva um número inteiro: '))
if n % 2 == 0:
    print('O número', n, 'é par')
else:
    print('O número', n, 'é ímpar')

# %%
# F = (C * 1.8) + 32
temp = float(input('Enter the temperature to be converted: '))
mode = input('Type FC to convert from Fahrenheit to Celsius or CF to convert from Celsius to Fahrenheit: ')

if mode == 'FC':
    result = (temp - 32) / 1.8
    print('The temperature', temp, 'ºF is equal to', result, 'ºC')
elif mode == 'CF':
    result = (temp * 1.8) + 32
    print('The temperature', temp, 'ºC is equal to', result, 'ºF')
else:
    print('Invalid mode entered. Please enter either FC or CF.')

# %%
#This program calculate a perons

hrs = input("Enter Hours: ")
rate = input("Enter Rate: ")
#try:
h = float(hrs)
r = float(rate)
#except:
    #print('Use Numbers, Please!')

if h > 40 :
    base = h * r
    over = (h - 40) * (r * 0.5)
    pay = base + over
else :
    pay = h * r

print(pay)
# Out:
# Enter Hours: 12
# Enter Rate: 5
# 60.0

# %%
n1 = int(input('type a number: '))
print(n1, ' is a ', type(n1))
# Out:
# type a number: 7
# 7  is a  <class 'int'>

# %%
name = input('Enter file:')
handle = open(name, 'r')
counts = dict()

for line in handle:
    words = line.split()
    for word in words:
        counts[word] = counts.get(word, 0) + 1

bigcount = None
bigword = None
for word, count in list(counts.items()):
    if bigcount is None or count > bigcount:
        bigword = words
        bigcount = count

print(bigword, bigcount)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-49758e7632ea> in <cell line: 1>()
# ----> 1 name = input('Enter file:')
#       2 handle = open(name, 'r')
#       3 counts = dict()
#       4
#       5 for line in handle:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
dia = input('Dia?')
mes = input('Mes?')
ano = input('Ano?')
print(dia, '/', mes, '/', ano)

nzt = input('Enter your name: ')
print('Hello', nzt )

hrs = input("Enter Hours:")
rate = input('Enter Rate:')
pay = float(hrs) * float(rate)
print('Pay:', pay)

# %%
# Exercício 3: crie um programa que leia dois números e mostre a soma entre eles
n1 = float(input('Digite um número: '))
n2 = float(input('Digite outro número: '))
s = n1 + n2
print('A soma entre {0} e {1} é igual a {2}'.format(n1, n2, s))

# %%
# Faça um programa que leia algo que mostre na tela o seu tipo primitivo e todas as possiveis informações sobre
x = input('Digite algo: ')
print('O tipo primitivo de {} é: '.format(x), type(x))
print('O que foi digitado é alfabético? ', x.isalpha())
print('O que foi gigitado é numérico? ', x.isnumeric())
print('O que foi digitado é alfanumérico? ', x.isalnum())
print('O que foi digitado está tudo em maiúsculo? ', x.isupper())
print('O que foi digitado está tudo em minúsculo? ', x.islower())
print('O que foi digitado é somente espaço? ', x.isspace())
print('O que foi digitado está capitalizado? ', x.iscapitalize()) # primeira letra Maiúscula?

# %%
# Montar um programa que pede um número, mostra seu antecessor e seu sucessor
n = int(input('Digite um valor inteiro: '))
ant = n - 1
suc = n + 1
print('O antecessor de {} vale {}, e o sucessor vale {}'.format(n, ant, suc))

# %%
# código que pede um número, retorna o dobro, triblo, e raiz quadrada
n = int(input('Digite um valor inteiro:'))
dobro = n * 2
triplo = n * 3
raiz = n ** (1/2)
print('Sendo n = {} \n {} x 2 = {} \n {} x 3 = {} \n A raiz quadrada de {} vale {}'
      . format(n, n, dobro, n, triplo, n, raiz))

# %%
# Duas notas de um aluno, calcula e mostra a média
# confirmar o resultado!!! ordem de precedencia
print('Olá, a minha função é calcular a média de duas avaliações do seu aluno!')
n1 = float(input('Digite um valor: '))
n2 = float(input('Digite outro valor: '))
med = (n1 + n2)/2
print('A média das notas vale {}'.format(med))

# %%
# lê um valor em metros, converte em cm e mm lê um valor em metros, converte em cm e mm
m = float(input('Digite a sua medida em metros: '))
cm = m * 100
mm = m * 1000
print('Sua medida de {} m equivale a {} cm e {} mm'.format(m, cm, mm))

# %%
# um programa que leia um número qualquer, e mostre sua tabuada
n = int(input('Digite um número para gerar a sua tabuada: '))
print('-'*10)
print('1 x {} = {}'.format(n, n * 1))
print('2 x {} = {}'.format(n, n * 2))
print('3 x {} = {}'.format(n, n * 3))
print('4 x {} = {}'.format(n, n * 4))
print('5 x {} = {}'.format(n, n * 5))
print('6 x {} = {}'.format(n, n * 6))
print('7 x {} = {}'.format(n, n * 7))
print('8 x {} = {}'.format(n, n * 8))
print('9 x {} = {}'.format(n, n * 9))
print('10 x {} = {}'.format(n, n * 10))
print('-'*10)

# %%
# Converta um valor em Real para Dólar
real = float(input('Quantos reais você quer converter em dólar? '))
dolar = real * 0.178
print('BRL {:.2f} = USD {:.2f}'.format(real, dolar))

# %%
# entra altura e largura da parede, devolve área em m^2 e quantidade de Litro de tinta (1L - 2m^2)

altura = float(input('Digite a altura da parede: '))
largura = float(input('Digite a largura da parede: '))
area = altura * largura
tinta = area / 2
print('Para pintar uma parede com {} m de altura, e {} m de largura, com a área de {} m^2, utliza-se {} L de tinta.'
      .format(altura, largura, area, tinta))

# %%
# preço, retora novo preço com 5% de desconto
p = float(input('Digite o valor do produto: '))
desc = p * 0.05
np = p - desc
print('O valor do produto com 5% de desconto é: {}'.format(np))

# %%
# salario, novo salario com 15% de aumento
sal = float(input('Digite o salario: '))
aumento = sal * 0.15
novosal = sal + aumento
print('O novo salario vale: {}'.format(novosal))

# %%
# converção de ºC para ºF
c = float(input('Digite a temperatura em Celsius: '))
f = c * 1.8 + 32
# cada grau Fahrenheit equivale a 1.8 Celcius, e 32 graus de diferença
print('{} ºC = {} ºF'.format(c, f))

# %%
# Escreva um programa que pergunte a quantidade de Km percorridos por um carro alugado e a quantidade de dias pelos quais ele foi alugado.
# Calcule o preço a pagar, sabendo que o carro custa R$60 por dia e R$0,15 por Km rodado.

dist = float(input('Digite a distância percorrida: '))
dia = float(input('Digite a quantidade de dias alugados: '))
alug = dia * 60
fuel = dist * 0.15
pag = alug + fuel
print('O valor total a ser pago, BRL{} de aluguel + BRL{} de combustivel, somam BRL{}'.format(alug, fuel, pag))

# %%
# input num Real -> output a parte inteira

n = float(input('Digite um numero Real: '))
z = math.trunc(n) # "trunca" o numero, cortanto a casa decimal, diferente de um floor, que arredonda para baixo
print('A porção inteira do numero Real {} é {}'.format(n, z))

# %%
# inputa cateto oposto e adjacente, output hipotenusa

import math
cata = float(input('Digite o valor do cateto adjacente: ')) # cateto adjacente
cato = float(input('Digite o valor do cateto oposto: ')) # cateto oposto
hipo = (cata ** 2) + (cato ** 2)  # hipotenusa^2 = cata^2 + cato^2
hipo = math.sqrt(hipo)
print('A hipotenusa vale: {}'.format(hipo))

# %%
# inputa ângulo qualquer, output valor do seno, cosseno e tangente

import math
ang = math.radians(float(input('Digite o valor do ângulo: ')))
print('O seno vale {}'.format(math.sin(ang)))
print('O cosseno vale {}'.format(math.cos(ang)))
print('A tangente vale {}'.format(math.tan(ang)))

# %%
# Professor deseja sortear 1 aluno entre 4 para apagar o quadro. Input nome dos alunos, output 1 aluno aleatório

import random
aluno1 = input('Digite o nome de um aluno: ')
aluno2 = input('Digite o nome de mais um aluno: ')
aluno3 = input('Digite o nome de mais um aluno: ')
aluno4 = input('Digite o nome do último aluno: ')
turma = [aluno1, aluno2, aluno3, aluno4]
print(random.choice(turma))

# %%
# Mesmo professor quer definir a ordem de apresentação entre 4 alunos. Input 4 alunos, output uma ordem aleatória

import random
aluno1 = input('Digite o nome de um aluno: ')
aluno2 = input('Digite o nome de mais um aluno: ')
aluno3 = input('Digite o nome de mais um aluno: ')
aluno4 = input('Digite o nome do último aluno: ')
turma = [aluno1, aluno2, aluno3, aluno4]
random.shuffle(turma)
print(turma)

# %%
# Abre e reproduz um arquivo .mp3
import pygame
pygame.init()

pygame.mixer.music.load('stillAlive.mp3')
pygame.mixer.music.play()

clock = pygame.time.Clock()
while pygame.mixer.music.get_busy():
    clock.tick(60)
    pygame.event.poll()

# %%
# Ler nome e mostra com :
# todas maiusc
# todas minusc
# quantas letras ao todo sem espaço
# quantas letras no primeiro nome?
name = input('Enter your name: ')
print('All upper case:',name.upper())
print('All lower case:',name.lower())
nameNoSpace = ''.join(name.split()) # split the name and join with no spaces
print('The hole name has ',len(nameNoSpace),' letters') # counts the num of letters of the hole name
print('The first name has ',len(name.split()[0]),' letters') # counts the length of the first = 0 element of the list

# %%
# Ler entr 0 e 9999 e mostra cada um dos digitos separados, unidade, dezena, centena e milhar
num = int(input('Enter a number between 0 and 9999: '))
u = num // 1 % 10
d = num // 10 % 10
c = num // 100 % 10
m = num // 1000 % 10
print('Número: {}'.format(num))
print('Unidade: {}'.format(u))
print('Dezena: {}'.format(d))
print('Centena: {}'.format(c))
print('Milhar: {}'.format(m))

# %%
# Ler nome de uma cidade e diz se começa ou não com o nome "SANTO"
c = (input('Digite o nome de uma cidade: '))
c = c.upper()
santo = 'SANTO' in c
print('A cidade ',c,' tem SANTO? ',santo)

# %%
# Ler nome e diz se tem "Silva"
nome = (input('Digite nome completo: '))
nome = nome.upper()
silva = 'SILVA' in nome
print('O nome ',nome,' tem SILVA? ',silva)

# %%
# Ler frase
# Quantas vezes aparece letra "A"
# Em que posição ela aparece a primeira vez?
# Em que posição ela aparece a última vez?
frase = input('Digite uma frase: ')
frase = frase.strip().upper() # .strip() remove spaces
firstA = frase.find('A')
lastA = frase.find('A'[-1])
print('Frase: ',frase)
print('O primeiro A parece na posição: ',firstA)
print('O último A aparece na posição: ',lastA)
